# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather['weather'][0]['description']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Description": city_description,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabedelo
# Processing Record 2 of Set 1 | mecca
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | kavieng
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | isangel
# Processing Record 10 of Set 1 | shubarshi
# Processing Record 11 of Set 1 | alibag
# Processing Record 12 of Set 1 | iquique
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | gagra
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | pisco
# Processing Record 17 of Set 1 | ixtapa
# Processing Record 18 of Set 1 | thurso
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 1 | razdolnoye
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | brighton
# Processing Record 23 of Set 1 | assis
# Processing Record 24 of Set 1 | margate
# Processing Record 25 of Set 1 | isiro
# Processing Record 26 of Set 1 | santa catalina
# Processing Record 27 of Set 1 | coihueco
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | bubaque
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | narok
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | monrovia
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | port hedland
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | karpathos
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | berlevag
# Processing Record 47 of Set 1 | terra santa
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | lata
# Processing Record 2 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 3 of Set 2 | olinda
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | bekhtery
# Processing Record 6 of Set 2 | cayenne
# Processing Record 7 of Set 2 | mahanje
# Processing Record 8 of Set 2 | chapais
# Processing Record 9 of Set 2 | rio cuarto
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | marienburg
# Processing Record 13 of Set 2 | zorgo
# Processing Record 14 of Set 2 | mvuma
# Processing Record 15 of Set 2 | nome
# Processing Record 16 of Set 2 | avera
# Processing Record 17 of Set 2 | lazaro cardenas
# Processing Record 18 of Set 2 | santiago del estero
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | sao felix do xingu
# Processing Record 21 of Set 2 | asau
# Processing Record 22 of Set 2 | quelimane
# Processing Record 23 of Set 2 | bukama
# Processing Record 24 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 2 | havre-saint-pierre
# Processing Record 27 of Set 2 | kloulklubed
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | henties bay
# Processing Record 30 of Set 2 | qinhuangdao
# Processing Record 31 of Set 2 | moctezuma
# Processing Record 32 of Set 2 | lujan
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | atambua
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | long xuyen
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | tessalit
# Processing Record 41 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | dunedin
# Processing Record 47 of Set 2 | tadine
# Processing Record 48 of Set 2 | souillac
# Processing Record 49 of Set 2 | trimbak
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | nyagan
# Processing Record 2 of Set 3 | padang
# Processing Record 3 of Set 3 | meulaboh
# Processing Record 4 of Set 3 | narsaq
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | mnogovershinnyy
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | zheleznodorozhnyy
# Processing Record 13 of Set 3 | punta alta
# Processing Record 14 of Set 3 | phitsanulok
# Processing Record 15 of Set 3 | camacha
# Processing Record 16 of Set 3 | hambantota
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | svetlogorsk
# Processing Record 19 of Set 3 | kedrovyy
# Processing Record 20 of Set 3 | bahia blanca
# Processing Record 21 of Set 3 | tura
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | aykhal
# Processing Record 24 of Set 3 | nasice
# Processing Record 25 of Set 3 | wahiawa
# Processing Record 26 of Set 3 | rawson
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | carnarvon
# Processing Record 29 of Set 3 | alta floresta
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | itarema
# Processing Record 32 of Set 3 | hermanus
# Processing Record 33 of Set 3 | katsuura
# Processing Record 34 of Set 3 | trairi
# Processing Record 35 of Set 3 | talnakh
# Processing Record 36 of Set 3 | poltava
# Processing Record 37 of Set 3 | khash
# Processing Record 38 of Set 3 | lagoa
# Processing Record 39 of Set 3 | salinopolis
# Processing Record 40 of Set 3 | doka
# Processing Record 41 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 3 | balkhash
# Processing Record 43 of Set 3 | umba
# Processing Record 44 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 3 | sorland
# Processing Record 46 of Set 3 | bilma
# Processing Record 47 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 3 | buraydah
# Processing Record 49 of Set 3 | manggar
# Processing Record 50 of Set 3 | waddan
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | port lincoln
# Processing Record 3 of Set 4 | esperance
# Processing Record 4 of Set 4 | isla mujeres
# Processing Record 5 of Set 4 | marsa matruh
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | angoche
# Processing Record 8 of Set 4 | shimoda
# Processing Record 9 of Set 4 | vung tau
# Processing Record 10 of Set 4 | alexandria
# Processing Record 11 of Set 4 | bowen
# Processing Record 12 of Set 4 | nishihara
# Processing Record 13 of Set 4 | faya
# Processing Record 14 of Set 4 | komsomolskiy
# Processing Record 15 of Set 4 | pedernales
# Processing Record 16 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 4 | sao filipe
# Processing Record 18 of Set 4 | mount gambier
# Processing Record 19 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | kirakira
# Processing Record 22 of Set 4 | alice springs
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | atuona
# Processing Record 25 of Set 4 | alofi
# Processing Record 26 of Set 4 | fairbanks
# Processing Record 27 of Set 4 | axim
# Processing Record 28 of Set 4 | ghanzi
# Processing Record 29 of Set 4 | butaritari
# Processing Record 30 of Set 4 | touros
# Processing Record 31 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 4 | camana
# Processing Record 34 of Set 4 | antalaha
# Processing Record 35 of Set 4 | ola
# Processing Record 36 of Set 4 | thunder bay
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | naze
# Processing Record 39 of Set 4 | sao miguel do araguaia
# Processing Record 40 of Set 4 | mayumba
# Processing Record 41 of Set 4 | goderich
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | songjianghe
# Processing Record 44 of Set 4 | viesca
# Processing Record 45 of Set 4 | nanortalik
# Processing Record 46 of Set 4 | lorengau
# Processing Record 47 of Set 4 | ca mau
# Processing Record 48 of Set 4 | bambous virieux
# Processing Record 49 of Set 4 | gat
# Processing Record 50 of Set 4 | lai
# Processing Record 1 of Set 5 | zhigansk
# Processing Record 2 of Set 5 | hofn
# Processing Record 3 of Set 5 | mereni
# Processing Record 4 of Set 5 | saskylakh
# Processing Record 5 of Set 5 | pitimbu
# Processing Record 6 of Set 5 | amahai
# Processing Record 7 of Set 5 | victoria
# Processing Record 8 of Set 5 | mar del plata
# Processing Record 9 of Set 5 | saint anthony
# Processing Record 10 of Set 5 | belaya gora
# Processing Record 11 of Set 5 | westport
# Processing Record 12 of Set 5 | krasnoselkup
# Processing Record 13 of Set 5 | aviles
# Processing Record 14 of Set 5 | faanui
# Processing Record 15 of Set 5 | port hardy
# Processing Record 16 of Set 5 | salalah
# Processing Record 17 of Set 5 | villa bisono
# Processing Record 18 of Set 5 | bhuj
# Processing Record 19 of Set 5 | imeni poliny osipenko
# Processing Record 20 of Set 5 | fukue
# Processing Record 21 of Set 5 | chhuikhadan
# Processing Record 22 of Set 5 | murray bridge
# Processing Record 23 of Set 5 | nara
# Processing Record 24 of Set 5 | periyanayakkanpalaiyam
# Processing Record 25 of Set 5 | bajil
# Processing Record 26 of Set 5 | trofors
# Processing Record 27 of Set 5 | cantaura
# Processing Record 28 of Set 5 | kieta
# Processing Record 29 of Set 5 | baghdad
# Processing Record 30 of Set 5 | dubrovnik
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | uvalde
# Processing Record 33 of Set 5 | ulladulla
# Processing Record 34 of Set 5 | airai
# Processing Record 35 of Set 5 | road town
# Processing Record 36 of Set 5 | ventspils
# Processing Record 37 of Set 5 | turukhansk
# Processing Record 38 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 39 of Set 5 | kompaniyivka
# Processing Record 40 of Set 5 | kamenka
# Processing Record 41 of Set 5 | chuy
# Processing Record 42 of Set 5 | khatanga
# Processing Record 43 of Set 5 | cabo san lucas
# Processing Record 44 of Set 5 | odweyne
# Processing Record 45 of Set 5 | vyartsilya
# Processing Record 46 of Set 5 | coihaique
# Processing Record 47 of Set 5 | newtonmore
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | ajdabiya
# Processing Record 50 of Set 5 | macheng
# Processing Record 1 of Set 6 | yar-sale
# Processing Record 2 of Set 6 | sisimiut
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | makakilo city
# Processing Record 5 of Set 6 | boende
# Processing Record 6 of Set 6 | marawi
# Processing Record 7 of Set 6 | mercedes
# Processing Record 8 of Set 6 | healdsburg
# Processing Record 9 of Set 6 | mujiayingzi
# Processing Record 10 of Set 6 | eyl
# Processing Record 11 of Set 6 | masuguru
# Processing Record 12 of Set 6 | zeya
# Processing Record 13 of Set 6 | bafang
# Processing Record 14 of Set 6 | ancud
# Processing Record 15 of Set 6 | ortakoy
# Processing Record 16 of Set 6 | cidreira
# Processing Record 17 of Set 6 | jijiga
# Processing Record 18 of Set 6 | la romana
# Processing Record 19 of Set 6 | auki
# Processing Record 20 of Set 6 | ponta do sol
# Processing Record 21 of Set 6 | skalat
# Processing Record 22 of Set 6 | lakatoro
# Processing Record 23 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 6 | ukiah
# Processing Record 25 of Set 6 | lyubim
# Processing Record 26 of Set 6 | puerto baquerizo moreno
# Processing Record 27 of Set 6 | klaksvik
# Processing Record 28 of Set 6 | mattru
# Processing Record 29 of Set 6 | key west
# Processing Record 30 of Set 6 | hit
# Processing Record 31 of Set 6 | lipari
# Processing Record 32 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 6 | srandakan
# Processing Record 34 of Set 6 | belen
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | chemainus
# Processing Record 37 of Set 6 | sarangani
# Processing Record 38 of Set 6 | kuandian
# Processing Record 39 of Set 6 | stepnyak
# Processing Record 40 of Set 6 | ponta delgada
# Processing Record 41 of Set 6 | saint george
# Processing Record 42 of Set 6 | almaty
# Processing Record 43 of Set 6 | olga
# Processing Record 44 of Set 6 | cherskiy
# Processing Record 45 of Set 6 | mirante do paranapanema
# Processing Record 46 of Set 6 | aksu
# Processing Record 47 of Set 6 | rosetown
# Processing Record 48 of Set 6 | beckley
# Processing Record 49 of Set 6 | houma
# Processing Record 50 of Set 6 | necochea
# Processing Record 1 of Set 7 | samarai
# Processing Record 2 of Set 7 | terrace
# Processing Record 3 of Set 7 | gidam
# Processing Record 4 of Set 7 | sheopur
# Processing Record 5 of Set 7 | aleksandrow lodzki
# Processing Record 6 of Set 7 | korla
# Processing Record 7 of Set 7 | mama
# Processing Record 8 of Set 7 | vostok
# Processing Record 9 of Set 7 | maragogi
# Processing Record 10 of Set 7 | camargo
# Processing Record 11 of Set 7 | norman wells
# Processing Record 12 of Set 7 | skelleftea
# Processing Record 13 of Set 7 | misheronskiy
# Processing Record 14 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 15 of Set 7 | gari
# Processing Record 16 of Set 7 | afua
# Processing Record 17 of Set 7 | beloha
# Processing Record 18 of Set 7 | bosobolo
# Processing Record 19 of Set 7 | geraldton
# Processing Record 20 of Set 7 | kaitangata
# Processing Record 21 of Set 7 | kuryk
# Processing Record 22 of Set 7 | caravelas
# Processing Record 23 of Set 7 | isla vista
# Processing Record 24 of Set 7 | ambositra
# Processing Record 25 of Set 7 | pangai
# Processing Record 26 of Set 7 | coahuayana
# Processing Record 27 of Set 7 | jimo
# Processing Record 28 of Set 7 | kalmunai
# Processing Record 29 of Set 7 | campbell river
# Processing Record 30 of Set 7 | rocky mountain house
# Processing Record 31 of Set 7 | sinjai
# Processing Record 32 of Set 7 | puerto carreno
# Processing Record 33 of Set 7 | tambura
# Processing Record 34 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 7 | pimentel
# Processing Record 36 of Set 7 | nikolskoye
# Processing Record 37 of Set 7 | hobart
# Processing Record 38 of Set 7 | augusto correa
# Processing Record 39 of Set 7 | inhambane
# Processing Record 40 of Set 7 | leningradskiy
# Processing Record 41 of Set 7 | kenai
# Processing Record 42 of Set 7 | alyangula
# Processing Record 43 of Set 7 | sao joao da barra
# Processing Record 44 of Set 7 | birao
# Processing Record 45 of Set 7 | kincardine
# Processing Record 46 of Set 7 | benguela
# Processing Record 47 of Set 7 | dudinka
# Processing Record 48 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 7 | bonavista
# Processing Record 50 of Set 7 | pevek
# Processing Record 1 of Set 8 | okhotsk
# Processing Record 2 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 3 of Set 8 | lykhivka
# Processing Record 4 of Set 8 | rio rancho
# Processing Record 5 of Set 8 | salta
# Processing Record 6 of Set 8 | sotnikovo
# Processing Record 7 of Set 8 | fortuna
# Processing Record 8 of Set 8 | arman
# Processing Record 9 of Set 8 | bandarbeyla
# Processing Record 10 of Set 8 | guerrero negro
# Processing Record 11 of Set 8 | suntar
# Processing Record 12 of Set 8 | pangnirtung
# Processing Record 13 of Set 8 | bereda
# Processing Record 14 of Set 8 | cururupu
# Processing Record 15 of Set 8 | nemuro
# Processing Record 16 of Set 8 | neiafu
# Processing Record 17 of Set 8 | broken hill
# Processing Record 18 of Set 8 | mitu
# Processing Record 19 of Set 8 | nanakuli
# Processing Record 20 of Set 8 | deputatskiy
# Processing Record 21 of Set 8 | kawhia
# Processing Record 22 of Set 8 | sitka
# Processing Record 23 of Set 8 | matata
# Processing Record 24 of Set 8 | morondava
# Processing Record 25 of Set 8 | colomi
# Processing Record 26 of Set 8 | andrelandia
# Processing Record 27 of Set 8 | gorom-gorom
# Processing Record 28 of Set 8 | ibra
# Processing Record 29 of Set 8 | beira
# Processing Record 30 of Set 8 | hobyo
# Processing Record 31 of Set 8 | bankura
# Processing Record 32 of Set 8 | amapa
# Processing Record 33 of Set 8 | victor harbor
# Processing Record 34 of Set 8 | lugovoy
# Processing Record 35 of Set 8 | sioux lookout
# Processing Record 36 of Set 8 | port macquarie
# Processing Record 37 of Set 8 | urusha
# Processing Record 38 of Set 8 | chakradharpur
# Processing Record 39 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 8 | ust-ishim
# Processing Record 41 of Set 8 | abalak
# Processing Record 42 of Set 8 | puerto del rosario
# Processing Record 43 of Set 8 | kupang
# Processing Record 44 of Set 8 | macapa
# Processing Record 45 of Set 8 | torbay
# Processing Record 46 of Set 8 | clermont
# Processing Record 47 of Set 8 | gambo
# Processing Record 48 of Set 8 | yatou
# Processing Record 49 of Set 8 | ribas do rio pardo
# Processing Record 50 of Set 8 | fort nelson
# Processing Record 1 of Set 9 | kalaleh
# Processing Record 2 of Set 9 | hagere selam
# Processing Record 3 of Set 9 | kjopsvik
# Processing Record 4 of Set 9 | mlimba
# Processing Record 5 of Set 9 | charlestown
# Processing Record 6 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 9 | adrar
# Processing Record 8 of Set 9 | portland
# Processing Record 9 of Set 9 | tirumullaivasal
# Processing Record 10 of Set 9 | victoria point
# Processing Record 11 of Set 9 | berekum
# Processing Record 12 of Set 9 | chicama
# Processing Record 13 of Set 9 | gazojak
# Processing Record 14 of Set 9 | manica
# Processing Record 15 of Set 9 | hami
# Processing Record 16 of Set 9 | arlit
# Processing Record 17 of Set 9 | vila velha
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | masterton
# Processing Record 20 of Set 9 | patti
# Processing Record 21 of Set 9 | moose factory
# Processing Record 22 of Set 9 | batemans bay
# Processing Record 23 of Set 9 | tual
# Processing Record 24 of Set 9 | ust-omchug
# Processing Record 25 of Set 9 | shache
# Processing Record 26 of Set 9 | talcahuano
# Processing Record 27 of Set 9 | lons-le-saunier
# Processing Record 28 of Set 9 | mogadishu
# Processing Record 29 of Set 9 | koster
# Processing Record 30 of Set 9 | lokosovo
# Processing Record 31 of Set 9 | ornskoldsvik
# Processing Record 32 of Set 9 | richards bay
# Processing Record 33 of Set 9 | panevezys
# Processing Record 34 of Set 9 | antropovo
# Processing Record 35 of Set 9 | nandigama
# Processing Record 36 of Set 9 | kalangala
# Processing Record 37 of Set 9 | la ronge
# Processing Record 38 of Set 9 | phun phin
# City not found. Skipping...
# Processing Record 39 of Set 9 | sibu
# Processing Record 40 of Set 9 | ostersund
# Processing Record 41 of Set 9 | saint-georges
# Processing Record 42 of Set 9 | aklavik
# Processing Record 43 of Set 9 | niquelandia
# Processing Record 44 of Set 9 | conde
# Processing Record 45 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 46 of Set 9 | seoul
# Processing Record 47 of Set 9 | kabanjahe
# Processing Record 48 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 9 | hualmay
# Processing Record 50 of Set 9 | coalcoman
# City not found. Skipping...
# Processing Record 1 of Set 10 | danielskuil
# Processing Record 2 of Set 10 | tarakan
# Processing Record 3 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 10 | ruteng
# Processing Record 5 of Set 10 | rafai
# Processing Record 6 of Set 10 | cervo
# Processing Record 7 of Set 10 | nkhotakota
# Processing Record 8 of Set 10 | verkhnyaya inta
# Processing Record 9 of Set 10 | kosh-agach
# Processing Record 10 of Set 10 | mackay
# Processing Record 11 of Set 10 | barsovo
# Processing Record 12 of Set 10 | beringovskiy
# Processing Record 13 of Set 10 | teluk nibung
# Processing Record 14 of Set 10 | swift current
# Processing Record 15 of Set 10 | kneza
# City not found. Skipping...
# Processing Record 16 of Set 10 | flinders
# Processing Record 17 of Set 10 | ipoti
# Processing Record 18 of Set 10 | lompoc
# Processing Record 19 of Set 10 | eenhana
# Processing Record 20 of Set 10 | kaka
# Processing Record 21 of Set 10 | clyde river
# Processing Record 22 of Set 10 | tautira
# Processing Record 23 of Set 10 | grindavik
# Processing Record 24 of Set 10 | kidal
# Processing Record 25 of Set 10 | bow island
# Processing Record 26 of Set 10 | wanganui
# Processing Record 27 of Set 10 | san patricio
# Processing Record 28 of Set 10 | rio grande
# Processing Record 29 of Set 10 | doha
# Processing Record 30 of Set 10 | phulabani
# Processing Record 31 of Set 10 | jiutai
# Processing Record 32 of Set 10 | namibe
# Processing Record 33 of Set 10 | camabatela
# Processing Record 34 of Set 10 | inuvik
# Processing Record 35 of Set 10 | enfield
# Processing Record 36 of Set 10 | amambai
# Processing Record 37 of Set 10 | yeppoon
# Processing Record 38 of Set 10 | poum
# Processing Record 39 of Set 10 | girvan
# Processing Record 40 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 41 of Set 10 | corinto
# Processing Record 42 of Set 10 | polunochnoye
# Processing Record 43 of Set 10 | zverinogolovskoye
# Processing Record 44 of Set 10 | pak phanang
# Processing Record 45 of Set 10 | luderitz
# Processing Record 46 of Set 10 | san cristobal
# Processing Record 47 of Set 10 | mehamn
# Processing Record 48 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 10 | lima
# Processing Record 50 of Set 10 | ambon
# Processing Record 1 of Set 11 | hamilton
# Processing Record 2 of Set 11 | novichikha
# Processing Record 3 of Set 11 | fujin
# Processing Record 4 of Set 11 | sompeta
# Processing Record 5 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 11 | cornwall
# Processing Record 7 of Set 11 | hirara
# Processing Record 8 of Set 11 | comodoro rivadavia
# Processing Record 9 of Set 11 | guozhen
# Processing Record 10 of Set 11 | nyurba
# Processing Record 11 of Set 11 | nioro
# Processing Record 12 of Set 11 | havoysund
# Processing Record 13 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 11 | duluth
# Processing Record 15 of Set 11 | minab
# Processing Record 16 of Set 11 | kichmengskiy gorodok
# Processing Record 17 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 18 of Set 11 | segovia
# Processing Record 19 of Set 11 | bathsheba
# Processing Record 20 of Set 11 | muroto
# Processing Record 21 of Set 11 | killybegs
# Processing Record 22 of Set 11 | xining
# Processing Record 23 of Set 11 | te anau
# Processing Record 24 of Set 11 | san policarpo
# Processing Record 25 of Set 11 | christchurch
# Processing Record 26 of Set 11 | qaqortoq
# Processing Record 27 of Set 11 | ambovombe
# Processing Record 28 of Set 11 | biak
# Processing Record 29 of Set 11 | montepuez
# Processing Record 30 of Set 11 | aljezur
# Processing Record 31 of Set 11 | laguna
# Processing Record 32 of Set 11 | kulhudhuffushi
# Processing Record 33 of Set 11 | fraserburgh
# Processing Record 34 of Set 11 | walvis bay
# Processing Record 35 of Set 11 | nuuk
# Processing Record 36 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 11 | khani
# Processing Record 38 of Set 11 | ondjiva
# Processing Record 39 of Set 11 | sakakah
# Processing Record 40 of Set 11 | porto nacional
# Processing Record 41 of Set 11 | bani
# Processing Record 42 of Set 11 | kashi
# Processing Record 43 of Set 11 | najran
# Processing Record 44 of Set 11 | urman
# Processing Record 45 of Set 11 | balabac
# Processing Record 46 of Set 11 | la primavera
# Processing Record 47 of Set 11 | praya
# Processing Record 48 of Set 11 | bima
# Processing Record 49 of Set 11 | tallahassee
# Processing Record 50 of Set 11 | pinega
# Processing Record 1 of Set 12 | krutinka
# Processing Record 2 of Set 12 | bikin
# Processing Record 3 of Set 12 | peniche
# Processing Record 4 of Set 12 | haines junction
# Processing Record 5 of Set 12 | conceicao do araguaia
# Processing Record 6 of Set 12 | teknaf
# Processing Record 7 of Set 12 | vao
# Processing Record 8 of Set 12 | segamat
# Processing Record 9 of Set 12 | mulchen
# Processing Record 10 of Set 12 | torit
# Processing Record 11 of Set 12 | wanning
# Processing Record 12 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set 12 | bahia honda
# Processing Record 14 of Set 12 | fare
# Processing Record 15 of Set 12 | san quintin
# Processing Record 16 of Set 12 | meybod
# Processing Record 17 of Set 12 | thessalon
# Processing Record 18 of Set 12 | altay
# Processing Record 19 of Set 12 | vredendal
# Processing Record 20 of Set 12 | picton
# Processing Record 21 of Set 12 | barberton
# Processing Record 22 of Set 12 | saint-leu
# Processing Record 23 of Set 12 | fairview
# Processing Record 24 of Set 12 | kirillov
# Processing Record 25 of Set 12 | acapulco
# Processing Record 26 of Set 12 | bela
# Processing Record 27 of Set 12 | marzuq
# Processing Record 28 of Set 12 | savalou
# Processing Record 29 of Set 12 | iracoubo
# Processing Record 30 of Set 12 | jiuquan
# Processing Record 31 of Set 12 | shiyan
# Processing Record 32 of Set 12 | bilibino
# Processing Record 33 of Set 12 | taganak
# Processing Record 34 of Set 12 | kursavka
# Processing Record 35 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 12 | cootamundra
# Processing Record 37 of Set 12 | krasnokamensk
# Processing Record 38 of Set 12 | omboue
# Processing Record 39 of Set 12 | darhan
# Processing Record 40 of Set 12 | orgun
# City not found. Skipping...
# Processing Record 41 of Set 12 | lucea
# Processing Record 42 of Set 12 | dawlatabad
# Processing Record 43 of Set 12 | kovdor
# Processing Record 44 of Set 12 | gnjilane
# Processing Record 45 of Set 12 | atar
# Processing Record 46 of Set 12 | sembe
# Processing Record 47 of Set 12 | coquimbo
# Processing Record 48 of Set 12 | cerro punta
# Processing Record 49 of Set 12 | saint-francois
# Processing Record 50 of Set 12 | carutapera
# Processing Record 1 of Set 13 | henderson
# Processing Record 2 of Set 13 | ribeira grande
# Processing Record 3 of Set 13 | sovetskiy
# Processing Record 4 of Set 13 | navoi
# Processing Record 5 of Set 13 | karratha
# Processing Record 6 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 13 | maceio
# Processing Record 8 of Set 13 | esqueda
# Processing Record 9 of Set 13 | pauini
# Processing Record 10 of Set 13 | zyryanka
# Processing Record 11 of Set 13 | tabou
# Processing Record 12 of Set 13 | morada nova
# Processing Record 13 of Set 13 | jalu
# Processing Record 14 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | kiama
# Processing Record 16 of Set 13 | hovd
# Processing Record 17 of Set 13 | diamantino
# Processing Record 18 of Set 13 | mareeba
# Processing Record 19 of Set 13 | sodertalje
# City not found. Skipping...
# Processing Record 20 of Set 13 | tevriz
# Processing Record 21 of Set 13 | patitirion
# Processing Record 22 of Set 13 | cao bang
# Processing Record 23 of Set 13 | trinidad
# Processing Record 24 of Set 13 | matara
# Processing Record 25 of Set 13 | bariri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [raw]
# len(city_data)

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City       Description      Lat       Lng  Max Temp  Humidity  \
# 0     Cabedelo  scattered clouds  -6.9811  -34.8339     77.67        82
# 1        Mecca   overcast clouds  21.4267   39.8261     77.76        54
# 2     Tasiilaq        few clouds  65.6145  -37.6368      8.76        80
# 3  New Norfolk         clear sky -42.7826  147.0587     69.91        42
# 4      Kavieng     broken clouds  -2.5744  150.7967     83.59        72
#
#    Cloudiness  Wind Speed Country                 Date
# 0          46       11.45      BR  2021-12-28 08:20:58
# 1          96        5.68      SA  2021-12-28 08:24:44
# 2          11        5.28      GL  2021-12-28 08:18:31
# 3           1        5.48      AU  2021-12-28 08:25:36
# 4          60        4.74      PG  2021-12-28 08:27:55

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0     Cabedelo      BR  2021-12-28 08:20:58  -6.9811  -34.8339     77.67
# 1        Mecca      SA  2021-12-28 08:24:44  21.4267   39.8261     77.76
# 2     Tasiilaq      GL  2021-12-28 08:18:31  65.6145  -37.6368      8.76
# 3  New Norfolk      AU  2021-12-28 08:25:36 -42.7826  147.0587     69.91
# 4      Kavieng      PG  2021-12-28 08:27:55  -2.5744  150.7967     83.59
# 5      Rikitea      PF  2021-12-28 08:25:37 -23.1203 -134.9692     75.38
# 6     Thompson      CA  2021-12-28 08:20:46  55.7435  -97.8558    -14.64
# 7       Albany      US  2021-12-28 08:20:52  42.6001  -73.9662     34.66
# 8      Isangel      VU  2021-12-28 08:25:38 -19.5500  169.2667     81.93
# 9    Shubarshi      KZ  2021-12-28 08:27:56  48.5872   57.1869     27.41
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        82          46       11.45  scattered clouds
# 1        54          96        5.68   overcast clouds
# 2        80          11        5.28        few clouds
# 3        42           1        5.48         clear sky
# 4        72          60        4.74     broken clouds
# 5        86         100       22.30        light rain
# 6        76          20        6.91        few clouds
# 7        90         100        4.59   overcast clouds
# 8        79         100        1.74   overcast clouds
# 9        95         100        4.36        light snow

# %%
# Create the output file (CSV).
output_data_file = "weather_database/weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
